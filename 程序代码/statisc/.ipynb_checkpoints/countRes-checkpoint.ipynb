# %%
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu,SmoothingFunction
import pandas as pd
import numpy as np
import docker
import os
import re
import random
from string import punctuation
import json
import matplotlib.pyplot as plt
import pickle
punc = punctuation
smooth = SmoothingFunction()

# %%
#countGasRes
def countGasRes(data):
    #patNum = [1,6,2,3,4,7] 雀屏论文顺序有误 这个顺序对应1，2，3，4，5，6
    for item in [1,6,2,3,4,7]:
        print(item,end=' ')
        print(len(data[data['pattern{}'.format(item)].apply(lambda x : x != None and len(x) > 0)]))
        
#countBugRes
def smallerRange(oldNum, lineNum):
    if len(oldNum) < 1 or len(lineNum) < 1:
        print('great error')
        return False
    oldStart = oldNum[0]
    oldEnd = oldNum[-1]
    lineStart = lineNum[0]
    lineEnd = lineNum[-1]
    return lineStart >= oldStart and lineEnd <= oldEnd
def updateMap(res, title, lineNum):
    lineNum = [lineNum] if type(lineNum) == int else lineNum
    lineOldNum = res[title]
    for oldNum in lineOldNum:
        #print(oldNum)
        if smallerRange(oldNum, lineNum):
            return
    res[title].append(lineNum)
    
def subDict(dict1, dict2):
    res = {}
    for item in dict1.keys():
        if item not in dict2.keys():
            res[item] = dict1[item]
        elif dict1[item] - dict2[item] > 0:
            res[item] = dict1[item] - dict2[item]
    return res
    
def getCount(mapRes):
    resCount = {}
    for item in mapRes:
        if len(item) > 0:
            for bugName in item.keys():
                count = len(item[bugName])
                if bugName in resCount.keys():
                    resCount[bugName] += count
                else:
                    resCount[bugName] = count
    return resCount

toolNames = ['mythril_analysis_not_info','osiris_analysis','slither_analysis_not_info']

def get(cc, toolNames):
    mapRes = []
    for index,row in cc.iterrows():
        #同行算消除
        res = {}
        for toolName in toolNames:
            #toolRes = row[toolName]
            toolRes =  eval(row[toolName]) if type(row[toolName]) == str else row[toolName]
            for tRes in toolRes:
                lineNum = tRes['lineno']
                title = mapp[toolName.split('_')[0]][tRes['title'].strip()]#已经转换过
                if title in res.keys():
                    updateMap(res, title, lineNum)
                else:
                    res[title] = [[lineNum] if type(lineNum) == int else lineNum]#使用lineNum--list的len计算数量 [[],[]]
            #temp = [res]
            #print(getCount(temp))
        mapRes.append(res)
    resCount =  getCount(mapRes)
    return resCount

def countBugRes(data):
    print('mythril: {}'.format( get(data, ['mythril_analysis_not_info']) ))
    print('osiris: {}'.format(subDict(get(data, ['mythril_analysis_not_info','osiris_analysis']), get(data, ['mythril_analysis_not_info']))))
    print('slither: {}'.format( subDict(get(data, ['mythril_analysis_not_info','osiris_analysis','slither_analysis_not_info']), get(data, ['mythril_analysis_not_info','osiris_analysis'])) ))
    print('total:',end=' ')
    total = get(data, ['mythril_analysis_not_info','osiris_analysis','slither_analysis_not_info'])
    count = 0
    for item in total:
        count += total[item]
    print(total)
    print(count)
#工具结果整合    
head = [' access_control ',
 ' arithmetic ',
 ' denial_service ',
 ' reentrancy ',
 ' unchecked_low_calls ',
 ' bad_randomness ',
 ' front_running ',
 ' time_manipulation ',
 ' short_addresses ',
 ' Other ',
 ' Ignore ']    
dic = dict(zip(head,[0]*10))
mapping = open('/home/yfliu/mapping.json').read()
mapp = json.loads(mapping)
slither_map = mapp['slither']
slither_key = slither_map.keys()
slither_type_map = dict(zip(slither_key,[0]*len(slither_key)))
u = open('/home/yfliu/paper/trash/temp.txt').read()
for i in u.splitlines():
    sp = i.split()
    slither_type_map[sp[1]] = sp[-2]
slither_type_map
slither_type_map['constant-function'] = 'Medium'
slither_bug_patch = ['constable-states','erc20-indexed','erc20-interface','external-function','incorrect-equality','naming-convention','shadowing-local','shadowing-state','shadowing-builtin','shadowing-abstract']

# %%
conMan = pd.read_pickle('/home/yfliu/paper_data/manualResultCsv/contractResGas.pic')
conAst = pd.read_pickle('/home/yfliu/paper_data/astResultCsv/contractResGas.pic')
conAstBleu = pd.read_pickle('/home/yfliu/paper_data/astResultCsv/contractResBleuGas.pic')
funMan = pd.read_pickle('/home/yfliu/paper_data/manualResultCsv/functionResGas.pic')
funAst = pd.read_pickle('/home/yfliu/paper_data/astResultCsv/functionResGas.pic')
funAstBleu = pd.read_pickle('/home/yfliu/paper_data/astResultCsv/functionResBleuGas.pic')
runList = [conAst,conAstBleu,conMan,funAst,funAstBleu,funMan]

# %%
conAst = pd.read_pickle('/home/yfliu/paper_data/astResultCsv/contractRes.pic')

# %%
conAst
# Out:
#       index  sni_index  code_index  \
# 0         0          2          46
# 1         1          8         993
# 2         2       6238         993
# 3         3         29       23020
# 4         4       1745       23020
# ...     ...        ...         ...
# 1017   1115       7049        2076
# 1018   1116       7060       30455
# 1019   1117       7082        3571
# 1020   1118       7093         459
# 1021   1119       7133       47066
#
#                                            code_name  \
# 0     0xcf2b19384ea3f027f8620db3f797ae61bb475125.sol
# 1     0x002842529757eab873cce9c251087e1b993f9200.sol
# 2     0x002842529757eab873cce9c251087e1b993f9200.sol
# 3     0x59f243d056ada87eb563c2d507fe4822f8ccccac.sol
# 4     0x59f243d056ada87eb563c2d507fe4822f8ccccac.sol
# ...                                              ...
# 1017  0x4333defa1bf3b49246666d1dea395f98e816a032.sol
# 1018  0xf4c13de243a7716fb7351736228c8337f460d760.sol
# 1019  0x5f002910d3e1bdcdcef62cbcc2b294618e9f7fad.sol
# 1020  0xc849a5fff9befa297d1c3a772bafac9f3c9004ec.sol
# 1021  0xa8f5b088245fe39316ec2719b15af4ba5dc91835.sol
#
#                                             dealed_code       sni_name  \
# 0     ['contract', 'multisig', 'event', 'Depositaddr...     7089-1.sol
# 1     ['contract', 'StupidToken', 'function', 'trans...    37927-0.sol
# 2     ['contract', 'StupidToken', 'function', 'trans...  37858-0-0.sol
# 3     ['contract', 'MSD4', 'function', 'greenOnFanCh...    84331-2.sol
# 4     ['contract', 'MSD4', 'function', 'greenOnFanCh...    84331-0.sol
# ...                                                 ...            ...
# 1017  ['contract', 'BitQueen', 'is', 'ERC20', 'strin...  66012-0-0.sol
# 1018  ['contract', 'DreamCarToken', 'function', 'get...  71855-1-0.sol
# 1019  ['contract', 'TokenPriveProviderInterface', 'f...  20864-1-0.sol
# 1020  ['contract', 'ERC223ReceivingContract', 'funct...  34224-0-0.sol
# 1021  ['contract', 'TLNConfig', 'string', 'public', ...  52444-0-0.sol
#
#                                           contract_code  \
# 0     contract multisig {\n\n\n\n    \n\n\n\n    \n\...
# 1     contract StupidToken {\n    function transferF...
# 2     contract StupidToken {\n    function transferF...
# 3     contract MSD4 {\n\n   \n\n    function greenOn...
# 4     contract MSD4 {\n\n   \n\n    function greenOn...
# ...                                                 ...
# 1017  contract BitQueen is ERC20 {\n\n  string publi...
# 1018  contract DreamCarToken {\n\n    function getFo...
# 1019  contract TokenPriveProviderInterface {\n\n    ...
# 1020  contract ERC223ReceivingContract {\n\n\n\n    ...
# 1021  contract TLNConfig {\n\n    string  public con...
#
#                                                sni_code contract_line  \
# 0     contract multisig { event Deposit(address from...    [570, 610]
# 1     contract MyToken {\n        function transferF...      [33, 35]
# 2     contract TheTokenContract {\n    \n    functio...      [33, 35]
# 3     contract Tested1 {\n    function func() public...      [36, 46]
# 4     contract Tested {\n    function func() public ...      [36, 46]
# ...                                                 ...           ...
# 1017  contract SimpleToken is ERC20 {\n\n  string pu...    [310, 328]
# 1018  contract A {\n    function someMethod(address ...      [16, 20]
# 1019  contract Storage {\n    function getEntityCoun...      [86, 90]
# 1020  contract ERC223Receiver\n{\n    function token...      [38, 56]
# 1021  contract TokenERC20 {\n    \n    string public...    [114, 119]
#
#                                             name  ... mythril_analysis  \
# 0     0xcf2b19384ea3f027f8620db3f797ae61bb475125  ...               []
# 1     0x002842529757eab873cce9c251087e1b993f9200  ...               []
# 2     0x002842529757eab873cce9c251087e1b993f9200  ...               []
# 3     0x59f243d056ada87eb563c2d507fe4822f8ccccac  ...               []
# 4     0x59f243d056ada87eb563c2d507fe4822f8ccccac  ...               []
# ...                                          ...  ...              ...
# 1017  0x4333defa1bf3b49246666d1dea395f98e816a032  ...               []
# 1018  0xf4c13de243a7716fb7351736228c8337f460d760  ...               []
# 1019  0x5f002910d3e1bdcdcef62cbcc2b294618e9f7fad  ...               []
# 1020  0xc849a5fff9befa297d1c3a772bafac9f3c9004ec  ...               []
# 1021  0xa8f5b088245fe39316ec2719b15af4ba5dc91835  ...               []
#
#      slither_analysis                              pattern1      pattern6  \
# 0                  []                                  None          None
# 1                  []                                  None            []
# 2                  []                                  None            []
# 3                  []                                  None            []
# 4                  []                                  None            []
# ...               ...                                   ...           ...
# 1017               []                                  None  [[317, 317]]
# 1018               []                                  None            []
# 1019               []                                  None    [[89, 89]]
# 1020               []                                  None    [[55, 55]]
# 1021               []  [[117, 117], [118, 118], [119, 119]]  [[119, 119]]
#
#      pattern2 pattern3 pattern4 pattern7 slither_analysis_not_info  \
# 0        None     None     None     None                        []
# 1        None     None     None     None                        []
# 2        None     None     None     None                        []
# 3        None     None     None     None                        []
# 4        None     None     None     None                        []
# ...       ...      ...      ...      ...                       ...
# 1017     None     None     None     None                        []
# 1018     None       []     None     None                        []
# 1019     None     None     None     None                        []
# 1020     None     None     None     None                        []
# 1021     None     None     None     None                        []
#
#      mythril_analysis_not_info
# 0                           []
# 1                           []
# 2                           []
# 3                           []
# 4                           []
# ...                        ...
# 1017                        []
# 1018                        []
# 1019                        []
# 1020                        []
# 1021                        []
#
# [1022 rows x 24 columns]

# %%
def compare(funMan, funAst):
    temp = list(set(funMan['sni_name']) - set(funAst['sni_name']))
    return (funMan[funMan['sni_name'].apply(lambda x : x in temp)][['sni_code', 'contract_code']])
temp = compare(conMan, conAst)
temp
# Out:
#                                               sni_code  \
# 8    contract Project {\n    bytes32 public value;\...
# 17   contract Owned {\n\n    address public owner;\...
# 29   contract Faucet {\n\n    function withdraw(uin...
# 32   contract TokenERC20 {\n    \n    string public...
# 33   contract MyToken {\n\n    string public name;\...
# ..                                                 ...
# 571  contract Test {\n\n    function getTime() publ...
# 650  contract Migrations {\n  address public owner;...
# 669  contract Owned {\n    \n    modifier noEther()...
# 689  contract mortal {\n\naddress owner;\n\nfunctio...
# 731  contract LockSlots is ERC20Token {\n\nusing Sa...
#
#                                          contract_code
# 8    contract Example {\n\n    uint256 public value...
# 17   contract Owned {\n    address public owner;\n ...
# 29   contract Faucet {\n\n    \n\n    \n\n    funct...
# 32   contract TokenERC20 {\n    \n    string public...
# 33   contract JCFv1 {\n    event Transfer(address i...
# ..                                                 ...
# 571  contract time{\nfunction _time() view external...
# 650  contract Migrations {\n  address public owner;...
# 669  contract Owned {\n    \n    modifier noEther()...
# 689  contract mortal\n{\n    address owner;\n\n    ...
# 731  contract LockSlots is ERC20Token {\n\n\n\n    ...
#
# [135 rows x 2 columns]

# %%
#新旧交集
#len(set(list(getNotNone(funAst, 'mythril_analysis_not_info')['index']) + list(getNotNone(funAst, 'slither_analysis_not_info')['index']) + list(getNotNone(funAst, 'osiris_analysis')['index'])))
#funAst.merge(funMan, on = ['sni_index'])
#conAst.merge(conMan,on = ['sni_code'])
#conAst.merge(conMan, how = 'right',on = ['sni_code', 'sni_name']).loc[796]['contract_code_y']
name = list(set(conMan['sni_name']) - set(conAst['sni_name']))

# %%
temp = conMan[conMan['sni_name'].apply(lambda x : x in name )]

# %%
#gas
for item in runList:
    countGasRes(item)
    print('-----------------')
# Out:
# 1 115
# 6 443
# 2 7
# 3 6
# 4 33
# 7 14
# -----------------
# 1 70
# 6 246
# 2 8
# 3 6
# 4 29
# 7 11
# -----------------
# 1 102
# 6 329
# 2 12
# 3 7
# 4 37
# 7 18
# -----------------
# 1 2
# 6 82
# 2 0
# 3 1
# 4 10
# 7 5
# -----------------
# 1 2
# 6 66
# 2 1
# 3 1
# 4 11
# 7 2
# -----------------
# 1 0
# 6 21
# 2 1
# 3 2
# 4 4
# 7 3
# -----------------

# %%
#bug
for item in runList:
    countBugRes(item)
    print('------------------')
# Out:
# mythril: {' arithmetic ': 211, ' reentrancy ': 207, ' Other ': 11, ' front_running ': 11, ' access_control ': 4}
# osiris: {' arithmetic ': 112, ' reentrancy ': 1, ' Ignore ': 27, ' time_manipulation ': 10, ' denial_service ': 1}
# slither: {' reentrancy ': 118, ' Other ': 115, ' unchecked_low_calls ': 118, ' time_manipulation ': 6, ' denial_service ': 19, ' access_control ': 15}
# total: {' arithmetic ': 323, ' reentrancy ': 326, ' Other ': 126, ' unchecked_low_calls ': 118, ' front_running ': 11, ' Ignore ': 27, ' time_manipulation ': 16, ' denial_service ': 20, ' access_control ': 19}
# 986
# ------------------
# mythril: {' arithmetic ': 120, ' reentrancy ': 14, ' Other ': 11, ' front_running ': 12, ' access_control ': 5}
# osiris: {' arithmetic ': 117, ' reentrancy ': 1, ' Ignore ': 28, ' time_manipulation ': 10, ' denial_service ': 1}
# slither: {' reentrancy ': 21, ' Other ': 7, ' time_manipulation ': 7, ' unchecked_low_calls ': 19, ' denial_service ': 16, ' access_control ': 16}
# total: {' arithmetic ': 237, ' reentrancy ': 36, ' Other ': 18, ' front_running ': 12, ' Ignore ': 28, ' time_manipulation ': 17, ' unchecked_low_calls ': 19, ' denial_service ': 17, ' access_control ': 21}
# 405
# ------------------
# mythril: {' arithmetic ': 139, ' reentrancy ': 23, ' access_control ': 7, ' front_running ': 17, ' Other ': 21}
# osiris: {' arithmetic ': 150, ' reentrancy ': 1, ' Ignore ': 30, ' time_manipulation ': 14, ' denial_service ': 2}
# slither: {' reentrancy ': 31, ' access_control ': 14, ' Other ': 17, ' time_manipulation ': 8, ' unchecked_low_calls ': 20, ' denial_service ': 21}
# total: {' arithmetic ': 289, ' reentrancy ': 55, ' access_control ': 21, ' front_running ': 17, ' Other ': 38, ' time_manipulation ': 22, ' unchecked_low_calls ': 20, ' Ignore ': 30, ' denial_service ': 23}
# 515
# ------------------
# mythril: {' Other ': 6, ' front_running ': 12, ' arithmetic ': 68, ' reentrancy ': 13, ' access_control ': 2}
# osiris: {' arithmetic ': 46, ' Ignore ': 8, ' time_manipulation ': 6, ' denial_service ': 2}
# slither: {' Other ': 4, ' reentrancy ': 11, ' unchecked_low_calls ': 7, ' time_manipulation ': 1, ' access_control ': 6, ' denial_service ': 1}
# total: {' Other ': 10, ' reentrancy ': 24, ' arithmetic ': 114, ' front_running ': 12, ' Ignore ': 8, ' unchecked_low_calls ': 7, ' time_manipulation ': 7, ' access_control ': 8, ' denial_service ': 3}
# 193
# ------------------
# mythril: {' Other ': 7, ' front_running ': 7, ' arithmetic ': 40, ' reentrancy ': 4, ' access_control ': 3}
# osiris: {' arithmetic ': 37, ' denial_service ': 1, ' Ignore ': 4, ' time_manipulation ': 6}
# slither: {' unchecked_low_calls ': 6, ' Other ': 2, ' reentrancy ': 8, ' time_manipulation ': 3, ' access_control ': 4}
# total: {' unchecked_low_calls ': 6, ' arithmetic ': 77, ' Other ': 9, ' front_running ': 7, ' reentrancy ': 12, ' denial_service ': 1, ' Ignore ': 4, ' time_manipulation ': 9, ' access_control ': 7}
# 132
# ------------------
# mythril: {' arithmetic ': 12, ' Other ': 3, ' front_running ': 2, ' reentrancy ': 1}
# osiris: {' arithmetic ': 12, ' Ignore ': 2, ' time_manipulation ': 1}
# slither: {' reentrancy ': 2}
# total: {' arithmetic ': 24, ' Other ': 3, ' front_running ': 2, ' Ignore ': 2, ' reentrancy ': 3, ' time_manipulation ': 1}
# 35
# ------------------

# %%
#至少一个不为空
bb[bb.osiris_analysis.apply(lambda x : x != []) | bb.mythril_analysis_not_info.apply(lambda x : x != []) | bb.slither_analysis_not_info.apply(lambda x : x != [])]

# %%
#diffuse -> http://localhost:8898/notebooks/paper_code/RQ6/RQ6.ipynb

# %%
#解决csv没法存储list的问题
'''
def evalItem(data):
    for item in data.columns:
        #print(item)
        data[item] = data[item].apply(lambda x : eval(x) if type(x) == str and '[' == x[0] else x)
    return data
conMan = pd.read_csv('/home/yfliu/paper_data/manualResultCsv/contractRes.csv')
conAst = pd.read_csv('/home/yfliu/paper_data/astResultCsv/contractRes.csv')
conAstBleu = pd.read_csv('/home/yfliu/paper_data/astResultCsv/contractResBleu.csv')
funMan = pd.read_csv('/home/yfliu/paper_data/manualResultCsv/functionRes.csv')
funAst = pd.read_csv('/home/yfliu/paper_data/astResultCsv/functionRes.csv')
funAstBleu = pd.read_csv('/home/yfliu/paper_data/astResultCsv/functionResBleu.csv')
evalItem(conMan).to_pickle('/home/yfliu/paper_data/manualResultCsv/contractRes.pic')
evalItem(conAst).to_pickle('/home/yfliu/paper_data/astResultCsv/contractRes.pic')
evalItem(conAstBleu).to_pickle('/home/yfliu/paper_data/astResultCsv/contractResBleu.pic')
evalItem(funMan).to_pickle('/home/yfliu/paper_data/manualResultCsv/functionRes.pic')
evalItem(funAst).to_pickle('/home/yfliu/paper_data/astResultCsv/functionRes.pic')
evalItem(funAstBleu).to_pickle('/home/yfliu/paper_data/astResultCsv/functionResBleu.pic')'''
